// %%
//getters and setters
class pen{
    String color;
    int tip;

    String getColor(){
        return this.color;
    }

    void setColor(String newColor){
        color = newColor;
    }
}

public class solution{
    public static void main(String args[]){
        String s = "blue";
        pen p = new pen(); // classname (object) = new whichclass();
        p.setColor(s);

        System.out.println(p.getColor());
    }
}

// %%
solution.main(null);
// Out:
// blue
