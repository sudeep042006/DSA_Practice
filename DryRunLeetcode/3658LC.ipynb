// %%
public static int getGCD(int a, int b){
    if(b == 0){
        return a;
    }

    return getGCD(b, a % b);
}

// %%
int n = 5;
int sumOdd = n * n;
int sumEven = n * (n + 1);

System.out.println(sumOdd);
System.out.println(sumEven);

getGCD(sumOdd, sumEven);
// Out:
// 25
// 30
// 5
